# %% [markdown]
# <div dir="rtl" style="text-align: center; line-height: 2; font-family: Tahoma;">
#     <b style="font-size: 20px;">سوال ۱ آمار توصیفی</b>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; line-height: 2; font-family: Tahoma; font-size: 16px;">
# در این سوال می‌خواهیم توزیع آگهی‌ها در دسته‌های مختلف را برای آگهی‌های سطح ۲ و سطح ۳ رسم کنیم.
# </div>

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Divar_Iran.csv", low_memory=False)

# %%
df["cat2_slug"].value_counts()
# Out:
# cat2_slug
# residential-sell        556798
# residential-rent        275325
# commercial-rent          76215
# commercial-sell          38691
# temporary-rent           29598
# real-estate-services     19312
# Name: count, dtype: int64

# %%
df["cat3_slug"].value_counts()
# Out:
# cat3_slug
# apartment-sell                        302244
# apartment-rent                        210927
# plot-old                              133098
# house-villa-sell                      121456
# house-villa-rent                       64398
# shop-rent                              45752
# shop-sell                              21738
# office-rent                            21329
# suite-apartment                        16241
# presell                                15700
# villa                                  12818
# industry-agriculture-business-sell     11827
# industry-agriculture-business-rent      9133
# office-sell                             5126
# partnership                             3612
# workspace                                539
# Name: count, dtype: int64

# %%
# Plot data distribution for cat2
plt.figure(figsize=(8, 5))
df["cat2_slug"].value_counts().plot(kind="bar")
plt.title("Distribution of Ads by Level 2 Category")
plt.xlabel("Level 2 Category")
plt.ylabel("Number of Ads")
plt.xticks(rotation=45)
plt.show()

# %%
# Plot data distribution for cat3
plt.figure(figsize=(10, 5))
df["cat3_slug"].value_counts().plot(kind="bar")
plt.title("Distribution of Ads by Level 3 Category")
plt.xlabel("Level 3 Category")
plt.ylabel("Number of Ads")
plt.xticks(rotation=90)
plt.show()
